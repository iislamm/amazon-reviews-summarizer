# %% [markdown]
# # Text Summarization using Deep Learning Model
# ## Developed by
#
# *   [Islam Mohamed](https://github.com/islammohamedd1)
# *   [Mostafa Yasser](https://github.com/mostafayasser)
# *   [Eslam Mamdouh](https://github.com/EslamMamdoouh)
#
# ## Problem Description and Background
# Companies and big businesses which offer online products face problems when analyzing the feedback of their customers. Usually, the feedback has a lot of unnecessary text in it. The long feedback is harder to analyze and consumes a huge amount of time.
# ### Solution
# The solution is to develop a learning agent to solve the problem. The agent is a deep learning model that summarizes the feedback using NLP techniques with Recurrent Neural Network to understand the context of the text and generate a summarization of the feedback text.

# %% [markdown]
# ### Import required libraries

# %%
import numpy as np  
import pandas as pd 
import re           
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords   
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load the dataset

# %%
# !wget --no-check-certificate  https://storage.googleapis.com/islamohamedd1.appspot.com/amazon-fine-food-reviews/Reviews.csv -O data.csv

data = pd.read_csv('data.csv', nrows=150000)
data.drop_duplicates(subset=['Text'],inplace=True)
data.dropna(axis=0,inplace=True)
# Out:
# --2020-05-13 14:32:29--  https://storage.googleapis.com/islamohamedd1.appspot.com/amazon-fine-food-reviews/Reviews.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.21.16, 2a00:1450:4006:807::2010
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.21.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 300904694 (287M) [text/csv]
# Saving to: ‘data.csv’
#
# data.csv            100%[===================>] 286.96M  1.12MB/s    in 4m 33s
#
# 2020-05-13 14:37:03 (1.05 MB/s) - ‘data.csv’ saved [300904694/300904694]

# %% [markdown]
# ### Extract, clean and format the data from the dataset
# * Contraction words are returned to their original
# * Stop words are removed from the reviews text
# * \_START_ and \_END_ tokens are inserted in the beggining and the ending of each label
# * The data is divided to be training data and test data

# %%
# contraction_mapping source: https://gist.github.com/aravindpai/f21a286e3cb8c68b199e4b6692ced40b#file-contraction-py
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",

                           "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",

                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",

                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",

                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",

                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",

                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",

                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",

                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",

                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",

                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",

                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",

                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",

                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",

                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",

                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",

                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",

                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",

                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",

                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",

                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",

                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",

                           "you're": "you are", "you've": "you have"}

contraction_mapping['<br>'] = ""

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')

stop_words = set(stopwords.words('english'))

def clean_sentences(data):
  new_data = []
  for s in data:
    new_s = s.lower()
    new_s = ' '.join([w for w in s.split() if not w in stop_words])
    new_s = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in new_s.split(" ")])
    new_data.append(new_s)
  return new_data


def clean_labels(data):
  new_data = []
  for s in data:
    new_s = s.lower()
    new_s = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in new_s.split(" ")])
    new_data.append(new_s)
  return new_data

labels = clean_labels(data['Summary'])
sentences = clean_sentences(data['Text'])
# Out:
# [nltk_data] Downloading package stopwords to /home/islam/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /home/islam/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
new_labels = []
for s in labels:
  new_s = s.split()
  new_s = ['_START_'] + new_s + ['_END_']
  new_labels.append(' '.join(new_s))
labels = new_labels

# %%
labels[:3]
# Out:
# ['_START_ good quality dog food _END_',
#  '_START_ not as advertised _END_',
#  '_START_ "delight" says it all _END_']

# %%
from sklearn.model_selection import train_test_split
training_sentences, testing_sentences, training_labels, testing_labels = train_test_split(sentences , labels,test_size=0.1 ,random_state=0 ,shuffle=True)

# %% [markdown]
# ### Tokenize the sentences
# The data is converted to be numeric tokens so the model can work with it easily

# %%
max_len = 80

x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(training_sentences)

x_training = x_tokenizer.texts_to_sequences(training_sentences) 
x_validation = x_tokenizer.texts_to_sequences(testing_sentences)

x_training = pad_sequences(x_training, maxlen=max_len, padding='post') 
x_validation = pad_sequences(x_validation, maxlen=max_len, padding='post')

x_vocab_size = len(x_tokenizer.word_index) + 1

# %%
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(training_labels)

y_training = y_tokenizer.texts_to_sequences(training_labels)
y_validation = y_tokenizer.texts_to_sequences(testing_labels)

y_training = pad_sequences(y_training, maxlen=max_len, padding='post')
y_validation = pad_sequences(y_validation, maxlen=max_len, padding='post')

y_vocab_size = len(y_tokenizer.word_index) + 1

# %%
x_vocab_size, y_vocab_size
# Out:
# (69883, 18277)

# %% [markdown]
# ### Create the model archeticure
# The model is usiing a LSTM (Long-Short-Term Memory) network for the encoder and another LSTM network for the decoder
#
# The Encoder-Decoder archeticure will work as illustrated below
# ![Enocder-Decoder archeticture](https://storage.googleapis.com/islamohamedd1.appspot.com/ai_project/encoder_decoder_diagram.jpeg)
#
#
# #### Encoder
# The encoder is composed of a LSTM network. The LSTM network starts with a 0 state as it's initial state. Then, the encoder network receives a word every timestamp. the word is passed to the first LSTM layer and processed, the LSTM layer pass the state after processing the word to the next LSTM layer. each LSTM layer receives the word from the input sequence and the previous state. Finally, the encoder outputs the final state.
#
# ![Encoder archeticture](https://storage.googleapis.com/islamohamedd1.appspot.com/ai_project/encoder_diagram.jpeg)
#
#
# #### Decoder
# The decoder LSTM network takes the final state of the encoder as it's initial state and the first word (start) as an input. Each LSTM layer in the decoder predicts the next word - y1, y2, etc - using the initial state of the encoder combined with the state of the previous LSTM state.
#
# ![Decoder archeticture](https://storage.googleapis.com/islamohamedd1.appspot.com/ai_project/decoder_diagram.jpeg)

# %%
from tensorflow.keras import backend as K
K.clear_session()
embidding_dim = 500

# Encoder
encoder_inputs = Input(shape=(max_len,))
encoder_embedding = Embedding(x_vocab_size, embidding_dim, trainable=True)(encoder_inputs)

encoder_lstm1 = LSTM(embidding_dim, return_sequences=True, return_state=True)
encoder_output1, sate_h1, state_c1 = encoder_lstm1(encoder_embedding)

encoder_lstm2 = LSTM(embidding_dim, return_sequences=True, return_state=True)
encoder_output2, state_h1, state_c1 = encoder_lstm2(encoder_output1)

encoder_lstm3 = LSTM(embidding_dim, return_state=True, return_sequences=True)
encoder_outputs, state_h, state_c = encoder_lstm3(encoder_output2)

# Decoder
decoder_inputs = Input(shape=(None,))
decoder_embedding_layer = Embedding(y_vocab_size, embidding_dim, trainable=True)
decoder_embedding = decoder_embedding_layer(decoder_inputs)

decoder_lstm = LSTM(embidding_dim, return_sequences=True, return_state=True)
decoder_outputs, decoder_fwd_state, decoder_back_state = decoder_lstm(decoder_embedding, initial_state=[state_h, state_c])

decoder_dense = TimeDistributed(Dense(y_vocab_size, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 80, 500)      34941500    input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 80, 500), (N 2002000     embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 80, 500), (N 2002000     lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 500)    9138500     input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 80, 500), (N 2002000     lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 500),  2002000     embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 18277)  9156777     lstm_3[0][0]
# ==================================================================================================
# Total params: 61,244,777
# Trainable params: 61,244,777
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['acc'])

# %% [markdown]
# ### Create a callback function to save the weights of the model after each epoch

# %%
import tensorflow as tf

checkpoint_path = "./model_weights/model_weights/cp.ckpt"

# %% [markdown]
# ### Load the model

# %%
model.load_weights(checkpoint_path)

# %% [markdown]
# ### Create a reveresed word_index to be able to get the text of each word using it's token

# %%
reverse_target_word_index=y_tokenizer.index_word 
reverse_source_word_index=x_tokenizer.index_word 
target_word_index=y_tokenizer.word_index

# %% [markdown]
# ### Set up the decoder model to be ready to generate summaries

# %%
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

decoder_state_input_h = Input(shape=(embidding_dim,))
decoder_state_input_c = Input(shape=(embidding_dim,))
decoder_hidden_state_input = Input(shape=(max_len, embidding_dim))

decoder_embedding2 = decoder_embedding_layer(decoder_inputs)

decoder_outputs2, state_h2, state_c2 = decoder_lstm(decoder_embedding2, initial_state=[decoder_state_input_h, decoder_state_input_c])

decoder_outputs2 = decoder_dense(decoder_outputs2)

decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2]
)

# %% [markdown]
# ### Decoding process
# The decoding process runs as follows
#
#
# 1. The decoding function takes the review to summarize as an input
# 2. The input review is entered in the encoder
# 3. The encoder state is used as the initial state for the decoder
# 4. The first input to the decoder is the word "start"
# 5. The decoder starts to generate the next words until it predicts the 'end' word or exceeds the maximum length for the summary.

# %%
def decode_sequence(input_sequence):
    encoder_out, encoder_h, encoder_c = encoder_model.predict(input_sequence)

    output_sequence = np.zeros((1,1))

    output_sequence[0, 0] = target_word_index['start']

    stop = False
    decoded_sentence = ''
    while not stop:
        output_tokens, h, c = decoder_model.predict([output_sequence] + [encoder_out, encoder_h, encoder_c])

        heighest_probability_token = np.argmax(output_tokens[0, -1, :])
        if (heighest_probability_token == 0):
          break
        hieghest_probability_word = reverse_target_word_index[heighest_probability_token]

        if (hieghest_probability_word != 'end'):
          decoded_sentence += ' ' + hieghest_probability_word

        if (hieghest_probability_word == 'end' or len(decoded_sentence.split()) >= 10 ):
          stop = True

        # Update the target sequence (of length 1).
        output_sequence = np.zeros((1,1))
        output_sequence[0, 0] = heighest_probability_token

        # Update internal states
        encoder_h, encoder_c = h, c

    return decoded_sentence

# %% [markdown]
# ### Test the model

# %%
def get_summary(input_sequence):
    newString=''
    for i in input_sequence:
      if((i!=0 and i!=target_word_index['start']) and i!=target_word_index['end']):
        newString=newString+reverse_target_word_index[i]+' '
    return newString

def get_text(input_sequence):
    newString = ''
    for i in input_sequence:
      if(i != 0):
        newString = newString + reverse_source_word_index[i] + ' '
    return newString

# %%
for i in range(200):
  original_summary = get_summary(y_validation[i])
  predicted_summary = decode_sequence(x_validation[i].reshape(1,max_len))
  print("Review:", get_text(x_validation[i]))
  print("Original summary:", original_summary)
  print("Predicted summary:", predicted_summary)

  print("\n")
# Out:
# Review: this favorite flavor stash tea adding little almond milk makes perfect also save way double price im getting stash tea amazon now
# Original summary: such a great save
# Predicted summary:  great tea
#
#
# Review: i pleasently surprised good juicy tasty papaya chunks opened can br br the soft juicy chunks right bite size make sure serve cold br br i mix native forest pineapple chunks delicous fruit bowl
# Original summary: fresh as can be for canned
# Predicted summary:  delicious
#
#
# Review: really good popcorn shipping costs much popcorn don't know worth it
# Original summary: amish popcorn
# Predicted summary:  great popcorn
#
#
# Review: we make son gluten free diet take lunch but love them
# Original summary: yummy
# Predicted summary:  great gluten free snack
#
#
# Review: like others said consistency stage 2 combo thin could thickened oatmeal cereal my 7 mth old loved flavor impatiently waited more baby foods i like contains spinach iron fruit antioxidants sweeten bit i use everyday i am home somewhat costly per pouch terrific option travel need something easy hand feed baby i tried squeezing contents pouch mouth particularly like i think that is used fed spoon an older baby could squeeze eat find without spoon great option
# Original summary: baby loved it convenient pouch
# Predicted summary:  good for a quick meal
#
#
# Review: my dogs love these keeps occupied cleans teeth my vet recommended dissolve dog's stomach need surgical removal large chunk swallowed
# Original summary: dogs love them
# Predicted summary:  great for dogs with allergies
#
#
# Review: when i received lickety stik i really sure expect dog turns i nothing worry crazy it if i even go near bottle starts wagging tail giving excited look one aspect doohickey i really like use reward pet without constantly give biscuit similar treat lick lickety stik trick the occasional biscuit treat okay much better active training highly recommend though may want shy away trying yourself
# Original summary: whoa my dog really likes this thing
# Predicted summary:  my dog loves these
#
#
# Review: these bombs hilarious we've ball family setting waiting response sure stinky run hills
# Original summary: fart
# Predicted summary:  great product
#
#
# Review: no offense vendor here 36 99 plus shipping 4 pack family sized bags outrageously overpriced especially consider order directly utz web site there 3 10 oz bags 12 99 5 10 oz bags 20 99 10 10 oz bags 39 99 or could even get 60 snack bags 17 99 not sure shipping utz mark up definitely steep br br if live east coast maine south carolina go check grocery store chips well worth it if fan area order utz
# Original summary: great chip but i am unsure why so expensive here
# Predicted summary:  the best
#
#
# Review: this cost in the super market 4 50 so why i going to pay almost 00 br for one can of this product
# Original summary: this is too expensive
# Predicted summary:  great product but overpriced
#
#
# Review: 30 years br a days ago i ordered 2lbs prosciutto de parma supplier amazon com and br i received today br the prosciutto carefully wrapped bubble pack put ice packs a br carton box marked perishable br the ham sweet delicious met expectation i happy it br in japan costs 2 5 times even including shipping charges supplier ny to br mn presumably high import duty br i assure disappointed this worth flying 7 000 miles from br tokyo minneapolis
# Original summary: sweet pork
# Predicted summary:  the best
#
#
# Review: these awful good the combination flavors actually nice cannot go wrong without chocolate coconut texture ruins all i understand often gluten free baking obstacles overcome bars feel like want cake like wind powdery almost tough time basically sort texture one imagines gluten free product would although way and i love almonds presence adds unpleasant feeling bar mouth br luckily i am gluten free i i imagine would nice pinch though i seek around
# Original summary: not so great
# Predicted summary:  not bad but not great
#
#
# Review: couldn't find store near us found seller we got great pricing fast shipping great transaction plan again
# Original summary: great coffee
# Predicted summary:  great product
#
#
# Review: my wife loves coffee i enjoy too caffiene gives buzz i drink decaf fair price great free delivery over 25 00
# Original summary: great cup of coffee
# Predicted summary:  great coffee
#
#
# Review: this cereal far i am concerned box yummy healthful crunch perfect breakfast late night snack
# Original summary: yummy and good for you
# Predicted summary:  great cereal
#
#
# Review: i angles cake mix pancake mix muffin mixes amazing im picky eater really close real thing trust wont settle less happy eating
# Original summary: gluten free
# Predicted summary:  delicious
#
#
# Review: previously used spice island beau monde seem equal quality br only tried spice island's shipping charges excessive
# Original summary: monde
# Predicted summary:  great product
#
#
# Review: the seasoning heavy i eat them i ordered bunch
# Original summary: ok but not fabulous
# Predicted summary:  good jerky
#
#
# Review: wanted make foods scratch much possible needed better system multiple appliances i used last time enter baby brezza remarkably impressed 5 star reviews well introduction videos i compared beaba babycook machine baby brezza came top every time i using past 2 weeks i love machine easy prep hearty steaming smooth purees easy clean up best all allows lot free time still feeding baby best foods possible best part all 100 br br between system i would choose million times over
# Original summary: makes being a granola mom so much easier
# Predicted summary:  great for travel
#
#
# Review: i got 12 year old cat stopped eating regular dry food kibble little hard teeth i ordered described soft kibble hard looked exactly science diet i feeding him he eagerly went food presented stopped eating bites hard luckily i buy huge bag food expensive
# Original summary: kibble is not softer
# Predicted summary:  my cats love it
#
#
# Review: i ordering while my dogs always liked last batch all sudden like leave lying around i thought smelled funny like chemical smell i first opened bag i called company they said would check it sent box replacement dog goodies guess i never thought much i read reviews chews making dogs sick guess i buy anymore
# Original summary: quality control
# Predicted summary:  do not buy
#
#
# Review: the greenies ordered amazon less expensive bricks mortar stores i plan order another box we received product days placing order br br terrific product lab loves treat
# Original summary: terrific product for doggie breath
# Predicted summary:  greenies
#
#
# Review: anything heavy strong enough for say huge pile meat cheese br br i top mine variety ways br br 1 maranatha organic no stir peanut butter organic super fruit spread br 2 goat cheese bruschetta topping chopped tomatoes basil onion splash red wine vinegar olive oil and let much liquid get onto cracker break or br 3 soft cream cheese chopped olives br br br br additional kudos ryvita fruit crispbread last time i checked still available amazon hopefully be
# Original summary: awesome crackers
# Predicted summary:  great product but the price is right
#
#
# Review: i bought tea way helping regulate system perform cleanse wow tea gentle certainly trick i highly recommend anyone wanting perform cleanse enjoys taste chamomile tea
# Original summary: tastes great does the trick
# Predicted summary:  great for traveling
#
#
# Review: i huge lavender fan never tried edible drinkable lavender products smell good i little concerned would taste funny even though i know smell taste tightly linked lavender seems like kind thing would smell way better tastes i glad find tea mostly tastes like stronger chamomile tea smells like lavender the best worlds
# Original summary: so relaxing
# Predicted summary:  a bit too strong for me
#
#
# Review: the photo 10 item package 3 just aware amazon using wrong item photo
# Original summary: the photo is deceptive
# Predicted summary:  product arrived damaged
#
#
# Review: earl grey always favorite i found stash's double bergamot i found tea heaven then problem finding it amazon makes easy keep steady supply
# Original summary: double delight
# Predicted summary:  best tea ever
# Review: ruby red great i wish people aware would available retail again tip even better mix sunrise orange i 4 quart pitcher i mix one pack fab
# Original summary: love this crystal light flavor it is the best
# Predicted summary:  good stuff
#
#
# Review: i tried product whim remembered ages ago buying kinder eggs kinder products canada enjoying them this excellent product hazelnut filling good wafers quite crisp the outer chocolate coating tasty well i wish american mass produced chocolate quality br br the chocolate come melted product description warn one refridgerate upon delivery hour when i so fine still quite fresh tasty considering i ordered early july exactly unexpected come melted matter quickly ship which shipped quickly aside
# Original summary: excellent chocolate bar
# Predicted summary:  delicious
#
#
# Review: my dogs loved toys even older dog never plays toys used kept get treat it they even fought other's kongs traded awhile a big christmas success dog toy
# Original summary: dog chew toys
# Predicted summary:  great product
#
#
# Review: this present grandmother loves tea she pleased get it i glad i bought sent her
# Original summary: present
# Predicted summary:  great tea
#
#
# Review: i happy find place i purchase larabars i get gluten free i love snacks thank carrying them
# Original summary: happy
# Predicted summary:  great product
#
#
# Review: great my favorite maple raisin world delicious i dedicated eating bowl hot oatmeal every morning i prepare nuking one minute half cup water stir bit i pour bit d br vanilla flavored non dairy almond milk light sprinkling sugar pure heaven please i connection manufacturer i know difficult small companies navigate rough economic cycles i beg you please support glutenfreeda trying product try locally buy box then realize delicious buy like i do case amazon s s discount free shipping
# Original summary: i am in love
# Predicted summary:  yummy
#
#
# Review: these dried bing cherries absolutely delicious i used wild rice toasted pecans side dish i plan use roast pork tenderloin soon excellent quality price
# Original summary: dried cherries are delicious
# Predicted summary:  great product
#
#
# Review: very tasty complaint oily if let sit cool develops fatty skin plastic spoon gets film i am eating i gave 5 stars anyway b c still best canned chicken rice soup i have ever tasted outside canned soup homemade always better
# Original summary: tasty but greasy chicken soup
# Predicted summary:  great soup
#
#
# Review: gets pay attention br br cons br careful leaving bag open treats dry out although i think put damp napkin re hydrate treats br these little expensive regular use especially bigger dog br br our dog medium sized easy go treats pretty quickly then again really need treats dog go wild for trick overall great treats we would recommend anyone looking high quality dog treats when finishes training day toss small handful around floor let hunt he terrier loves it
# Original summary: my dog loves these zukes
# Predicted summary:  my dog loves these
#
#
# Review: i purchased yummy treat whim wow i ever hooked i sent e mail company i could find anywhere desperate measures i guess br the cherry vanilla tops now i try flavors try like it
# Original summary: amazing addicting
# Predicted summary:  the best
#
#
# Review: golden malted makes best waffles we tried regular blueberry liked both thought we would give pumpkin try like pumpkin pie these came perfect crispy outside fluffy inside they overly sweet i cannot think way say right try em like em
# Original summary: this is the good stuff
# Predicted summary:  delicious
#
#
# Review: i have buying carob chips years no chips compare these right amount sweetness mimic chocolate they're great baking place choc chips also good themselves bag also customer service great folks barry farms awesome
# Original summary: outstanding
# Predicted summary:  delicious
#
#
# Review: the price certainly right i purchased came search vegan products this pasta not vegan contains egg white if problem you means purchase it fine every respect
# Original summary: it is good but not vegan
# Predicted summary:  not as good as the other brand
#
#
# Review: eating nearly 1 4 original diet i filled one bowl indoor cat food one bowl kitten food they barely touched indoor cat food eating kitten food i ended mix canned cat food get eat br br part might food triangular much larger kitten food they hard time eating first since used small pieces kitten food br br don't discouraged though my cat cannot tell difference kitten food regular adult food they really enjoy science diet's fish flavored food give try
# Original summary: not tastey
# Predicted summary:  my cats love it
#
#
# Review: my cats agree really love dry food i surprised even seemed like better epigen 90 i normally feed them no barf potty issues either eating food week whew lets hope still case i try non hairball formula
# Original summary: chicken is paw good
# Predicted summary:  my cats love it
#
#
# Review: works well power breeds heavy chewers if cheaper id buy dozen we pitbulls rottweilers far best choice keeping busy
# Original summary: great for larger dogs
# Predicted summary:  great product
#
#
# Review: this negative 3 star review the noodles squid ish taste texture i nearly gagged trying are bad or no calorie mush plant solubles really tastes horrific i eaten unique foods i wimp this would water board like torture could use me i ever got trouble
# Original summary: the worst thing i ever tasted
# Predicted summary:  not bad
#
#
# Review: the cereal great it came fresh i like buy bulk i always food hand
# Original summary: yum yum
# Predicted summary:  great cereal
#
#
# Review: my husband i discovered item shopping back fell love them fresh take microwave we like spices them you remember take microwave soon bag rises
# Original summary: pork rinds
# Predicted summary:  delicious
#
#
# Review: i bought a href http www amazon com gp product melon flavor a strawberry father i surprised i really liked melon father great time opening bottle strawberry he's type has know things work finishing drink went taking apart top bottle plus said was pretty good drink good compliment him br br we enjoyed drinks quite bit bottle made interesting conversation topic i am sure kids would love this
# Original summary: very good drinks
# Predicted summary:  good for you
#
#
# Review: guys cannot call coconut water product contains sugar that beverage would juice after yoga i went whole foods pick dinner hydrate i thought could good one minute i tasted i knew it sugar gross kinda last thing i wanted put body bikram session
# Original summary: it is not coconut water if it contains sugar
# Predicted summary:  not bad
#
#
# Review: cup measure 3 tablespoons slightly rounded place filter just would coffee fill max brew for sweet tea i use one 1 4 cup sugar per gallon it's easier put sugar gallon pitcher add hot liquid the sugar dissolve completely need much sugar when sugar dissolved add water ice bring gallon if pleased outcome try making adjustments once figure out it becomes routine probably one drinks make br enjoy br br ps i keep mine freezer ziplock i have opened box
# Original summary: best tea ever grocery stores are crazy for not stocking it
# Predicted summary:  great for iced tea
#
#
# Review: i understand would this they tried true product since corner rich malty flavored beverage market if wanted compete sickeningly sweet chocolate beverages slap new name keep market already have if i am going kicked curb sure would nice old ovaltine back creeps
# Original summary: new ovaltine is yukky
# Predicted summary:  a bit of sweet and sweet
#
#
# Review: i love popcorn i learn avoid popcorn setting microwave bag small popped corn begin burn 2 minutes the portion size right for added flavor i sprinkle mrs dash add teaspoon olive oil part mediterranean diet
# Original summary: nutritious low sodium calorie controlled tasty easy to prepare
# Predicted summary:  great popcorn
#
#
# Review: this sun butter absolutely fresh roasted sunflower seed taste i pleasantly surprised first taste shipping reasonable also i trust still i astounded good tastes
# Original summary: best sun butter ever by far
# Predicted summary:  delicious
#
#
# Review: my teeth hurt days trying eat 1 bag threw rest away i felt like i chewing fried pigs teeth
# Original summary: to tough to eat
# Predicted summary:  made in china
# Review: i fish driven cat vs chicken beef products absolutely loved them i keep wrapped something let smell away reach he could smell everything even though i couldn't he would ripped anything get them
# Original summary: cats favorite treat
# Predicted summary:  my cat loves it
#
#
# Review: i was expecting a lot more candy for that price and its not that good im very disappointed i wont be back for more unless the price drops by at least half
# Original summary: not that much candy for the price
# Predicted summary:  not as good as the original
#
#
# Review: it looks like dung tastes horrible if want experience disgusting yourself buy try it
# Original summary: terrible
# Predicted summary:  horrible
#
#
# Review: yesterday i decided i cans yet use i opened get rid dumping soup sausepan i could see consistency wonderfully creamy lots potatoes enough clams able call clam chowder i apologize anyone read first review chose purchase wonderful soup i serving soup lunch today i 1200 plus calories day i made commitment stay course year so far 201 days weight loss 40 pounds for 75 year old woman pretty good this delicious soup help make next 164 days easier thank progresso
# Original summary: delicious low calorie new england classic
# Predicted summary:  a must have for the pantry
#
#
# Review: my dogs love food times see picking dried veggies mix eating first kinda funny well started dogs food really bad gas problems they would stink room started eating one no stinky gas
# Original summary: begging for more
# Predicted summary:  my dog loves it
#
#
# Review: 7 family 2 celiac disease all love even picky eaters
# Original summary: huge hit
# Predicted summary:  great product
#
#
# Review: if like israeli couscous good buy it's cheaper local grocery the quality great complaints
# Original summary: great value
# Predicted summary:  good product
#
#
# Review: delicious i ordered french vanilla cappuccino i looking something delicious require extra effort adding cream sugar this exactly that i went 24 pack 2 3 weeks definitely ordering another box soon i would recommend anyone enjoys french vanilla flavor normally adds cream sugar coffee
# Original summary: delicious
# Predicted summary:  great coffee
#
#
# Review: this product claims perfect fix someone needs little extra energy product taste good well im sorry say product bitter worth money please dont money amazon allow returns product
# Original summary: nasty and bitter
# Predicted summary:  horrible
#
#
# Review: the chicken freeze dried medallions great my cat loves goes nuts whenever hears bag open br br the freeze dried medallions labelled supplemental feeding underwent feeding trials per customer service nature's variety i tend use treat mix raw instinct canned br br serving simple add warm water rehydrate wait minute done you also crumble add top foods storage simple well pouch zipper closure top br br customer service nature's variety also helpful
# Original summary: my cat loves this stuff
# Predicted summary:  great for older cats
#
#
# Review: jerky flavorful sweet salty pleasantly chewy too opposed dry stringy stuff i have tried elsewhere the price reasonable my main problem several bags went moldy within weeks several buyers complaint the first time i thought came way slipped me i checked bags arrived saw quickly turn fuzzy i realized i would eat within week two throw starts go bad it may moot since discontinued march 2011 i mind additives much would appreciate assuming bring back stuff could keep bit longer
# Original summary: very tasty but goes moldy quickly
# Predicted summary:  great for a quick snack
#
#
# Review: until the fda advises the products are safe again last month fda issued warning advising people buy chicken jerky treats made china unfortunately i hear warning late i gave dogs one yam good month result almost died vomiting bloody stool despite american sounding name canyon creek ranch is made in china and says so on the package even worse website amazon mention fda warning product toxic these lovely little treats nearly cost lives dogs well 500 vet bills time work
# Original summary: made in china fda says contaminated
# Predicted summary:  made in china
#
#
# Review: consume larger amounts omega fats downing supplements you could live longer need brush teeth chew gum more may become old person fish breath br br finally i note second shipment sent i never saw first box i told damaged delivery the product cold packed freezer packs lined box parthenon foods sent email damaged shipment offered refund re delivery hassles so easy work good communication i would order products again i have enough herring in my fridge to last a while
# Original summary: ordered both thick and filets products cold packed food
# Predicted summary:  great product but
#
#
# Review: everyone house even mother in law enjoyed drink it tastes much like quality soda made 100 real juice small cans mean consume lot calories once although healthier regular soda drink much still lot sugar
# Original summary: very popular at my house
# Predicted summary:  great alternative to soda
#
#
# Review: i am sorry contrast rave reviews product i like all i purchased several e v olive oils one disliked husband myself we tasted alone fresh bread dipping experienced funny feeling inside mouths dry throats made us cough this place kitchen sorry siciliani
# Original summary: did not like at all
# Predicted summary:  not what i expected
#
#
# Review: our entire family enjoy chips deluxe it good size snack bag easily split two toddlers they nice crunchy texture right amount sweetness without hard sugary tasting even warm weather get messy these still considered treat packets 9 ounces 25g 120 calories 5g fat
# Original summary: nice grab 'n go treat
# Predicted summary:  great snack
#
#
# Review: i yet use item product i rate four stars it packaged well time i update i get baking mood
# Original summary: better than wheat
# Predicted summary:  good stuff
#
#
# Review: when i looked box that is amazon i originally thought pasta honest i bother reading description upon receiving actually opening box found actually rice dinner little pieces broccoli barely seen after making boneless chicken breast putting everything together i must say turn pretty well actually taste good i personally spend money getting box since i am quite capable making rice broccoli dinner scratch want something quick running short time would good way prepare something simple dinner
# Original summary: picture on box misleading
# Predicted summary:  good for a quick meal
#
#
# Review: sense as make money nothing finding cutting bagging sell they cheap last long time after marrow chewed out antler still gnawed on flake off like bone eaten when antler gets smaller replaced new one could swallowed whole smaller size these lasted weeks so expense mind well worth it they sell weight dog use common sense a smaller one going softer larger one the larger one last longer smaller one long large dog cannot pick carry around hope around long time
# Original summary: perfect
# Predicted summary:  great product
#
#
# Review: chewing much work me given that primal strips heaven the texture close meat consistently chewable none gristle often associated beef jerky spam gooey real beef jerky makes jaw ache i end spitting gristle frequently but this this perfect if they replaced meat soylent brown type food i would happily leave real thing behind i am sure health benefits i guess good me i have seen people healthier i eating it i figure nutritious anyway tastes robust perfect texture perfect snack
# Original summary: better than meat says the carnivore
# Predicted summary:  delicious
#
#
# Review: these spicy chips lot great flavor warned left stanky breath afterwards the first time i ate night even brushing flossing i could taste mouth next morning so careful eat them especially hanging people later day
# Original summary: tasty but make sure you have gum
# Predicted summary:  good but not as good as the ones
#
#
# Review: oils exercise organic chemistry however want strong truffle flavor use lot oil dish smells like machine oil still lacks dense truffle taste br br looking oil top full can notice small dark oil droplets suspended ocean safflower oil there's many dark drops active ingredient so really buying expensive bottle safflower oil and last time remember eating truffles looked like motor oil looking drops dish there reason comes dark metal can enough said try another brand br br bottom line yuck
# Original summary: oil
# Predicted summary:  not exactly what i expected
# Review: love sure jell less sugar recipes granted still lot sugar way less full sugar recipes it sets softer side i like you really taste fruit i made strawberry jam pear jam excellent sure website recipes package insert
# Original summary: perfect
# Predicted summary:  great product
#
#
# Review: gift box a br br i emailed great northern customer service couple times question request sample know i could try it they never responded i took chance ordered some br br this time taking chance paid off it pops great tastes great too br br my issue 4 ounce pack overflows popcorn popping bowl my next order 2 5 oz packs br br bottom line regardless size stuff tastes tons better popcorn i have tried works great microwave popping bowl
# Original summary: pops perfectly in a microwave popping bowl
# Predicted summary:  great for baking
#
#
# Review: i love coffee i love chai lattes i love keurig but combination disgusting the taste first prepared strong ok i get could even even like it aftertaste kick in i never tasted much artificial sweetener product this listed lo cal diet i expecting i would rather aspirin dissolve mouth i returning store absolutely terrible
# Original summary: worst aftertaste ever even more then diet drinks
# Predicted summary:  tastes like plastic
#
#
# Review: first off blend not pure ethiopian coffee clear and open bag definitely see blend beans different sizes color basically dregs coffee beans harvested roasted generally i love ethiopian coffee but barely passes coffee let alone good coffee if i could give stars would review don't waste money skip it
# Original summary: this is the worse ethiopian coffee ever
# Predicted summary:  good coffee
#
#
# Review: i hard time finding store i find cheaper store great deal
# Original summary: great product
# Predicted summary:  great product
#
#
# Review: i love altoids cinnamon smalls i diabetic i use meals replace dessert the flavor strong one tiny mint satisfying
# Original summary: altoids cinnamon smalls
# Predicted summary:  yummy
#
#
# Review: my husband i absolutely fallen love rice it easy prepare tastes wonderful if like type rice try it you disappointed
# Original summary: awesome product
# Predicted summary:  delicious
#
#
# Review: we buy stacy's case go lot them and far shipments fresh crisp like grocery store significant savings
# Original summary: love stacy's pita chips
# Predicted summary:  yummy
#
#
# Review: this i expected i weaned extremely salty foods years ago the taste way salty kal yeast flakes better source vitamin b http www amazon com kal yeast flakes 22 flakes dp br br i 5 unopened jars i give away pay shipping
# Original summary: too salty
# Predicted summary:  great product but
#
#
# Review: of favors crackers kashi offers best one these slight sweet taste healthier crackers
# Original summary: classic
# Predicted summary:  great snack
#
#
# Review: sodium benzoate there 5 mg sodium listed label citric acid xanthan gum sucralose the splenda acesulfame potassium br br it's bargain 750 ml sold here i paid almost much local grocery store you'll probably use two tablespoons per drink more less you'll get money's worth add anything want hot chocolate iced tea etc maybe holiday's coming would nice change beverages well it also sold sugar added and several flavors without sugar click products torani top page br br cheers laurie
# Original summary: 0 calories 0 fat 0 carbs 0 sugar
# Predicted summary:  delicious and refreshing
#
#
# Review: i love market spice tea the decaf good regular great service handling order will definitely order again
# Original summary: more tea time
# Predicted summary:  great tea
#
#
# Review: very easy recipe turns fantastically cooper's products i used
# Original summary: excellent beer
# Predicted summary:  great for cooking
#
#
# Review: i readily admit i am coffee connosieur i like i like i cannot explain i like it i really liked blend i always hear people say decaf taste good i thought dark magic decaf tasty
# Original summary: a good first experience with k cups
# Predicted summary:  good coffee
#
#
# Review: i use muir glen crushed tomatoes the flavor whatever i cook dramatically improved nothing else even comes close i usually pay almost 2x grocery store standard crushed tomatoes even though i cheapy i never hesitate it's worth extra money without doubt
# Original summary: best crushed tomatoes
# Predicted summary:  great product but
#
#
# Review: the packaging item sufficient three bottles arrived broken caps quite annoying knocking one big bottles red coloring would make huge mess once remove paper seal bottle top nothing keep dye seeping cracked tops bottle gets knocked over this item needs package bubble wrap around prevent happening
# Original summary: broken caps
# Predicted summary:  great product but poor packaging
#
#
# Review: we could longer find item local supermarkets so glad found here who wants open packets lol
# Original summary: sweet as sugar
# Predicted summary:  my son loves these
#
#
# Review: all products 1st class i plan order items auction grandsons school thats best endorsement i give best wishes
# Original summary: i this organization
# Predicted summary:  great product
#
#
# Review: the price good awesome product as far dried cherries go brand excellent they still plump juicy full flavor not dried tasting like brands i put snack mix made sauce pork chops them rendered jam jelly like consistency eaten bag you sorry purchase these you able stop eating them
# Original summary: delicious
# Predicted summary:  delicious
#
#
# Review: great joints i eat like five day hack half white carpet rest sure make feel catnip ones would dat vet says gots lay nip bit pfffft he know i use medicinal purposes anyway br signed mr
# Original summary: yummy
# Predicted summary:  great for sensitive stomachs
#
#
# Review: arrived way christmas and luckily opened refrigerated enjoyed holidays
# Original summary: bacon
# Predicted summary:  great
#
#
# Review: versus processed cocoa the first thing i made i put much powder in alot much lol the second thing i made yup much again my kids i loving stuff they much willing drink homemade raw almond rice milk bit cacao honey it and so exciting my 12 year old drank green smoothie morning fuss all she told i would let drink chocolate almond milk could handle raw vegan milk drink enjoyed this definitely new pantry staple fact nutritious sweetens decision
# Original summary: wow for flavor
# Predicted summary:  great taste and texture
#
#
# Review: tastes great satisfies hunger i currently fitness diet i feel guilty i eating one these since melty ingredients stays tact hot cars beaches etc added bonus i took star calorie count bit high i chalk great taste fact fills up
# Original summary: a non guilty treat
# Predicted summary:  great for kids and adults
#
#
# Review: i like flavored coffee this one good the hazelnut also yummy most green kcups i tried delicious exception caramel vanilla cream taste like vanilla caramel creak i guess this kind taste like vanilla
# Original summary: good
# Predicted summary:  delicious
#
#
# Review: this aromatic tasty oil great salads scrambled eggs br i'm sure i will find uses time goes on free shipping br makes great deal my nit pick lid two three br bottles shipment tight lids difficult open
# Original summary: great value and taste
# Predicted summary:  great product
#
#
# Review: avocado oil high flash point used canola oil called for it give food yummy flavor and olive oil rich monounsaturated fatty acids low saturated fat our family loves it
# Original summary: healthy and delicious oil
# Predicted summary:  great olive oil
#
#
# Review: this shelter kitty tried since fed whiskas purrfectly chicken consider anything else he prepares eat i offer somthing else stops short bowl like he is sniffing food turns head walks away he eat brands products brand matter expensive the pouch convenient fact i know eat enjoy food makes it
# Original summary: passes all the tests
# Predicted summary:  my cats love it
#
#
# Review: excellent rub good basic chicken could original excellent amazing
# Original summary: excellent rub
# Predicted summary:  great
#
#
# Review: the stereotype decaf coffee bitter taste maxwell house this decaf coffee flavorful robust and great drink bed
# Original summary: wonderful and flavorful even decaf
# Predicted summary:  best decaf coffee
# Review: fan newman's own brand human food their salad dressings amazing however cat would eat product i purchased beef flavor loves beef flavored cat treats i give organic dry food time talking cat owners informed i mixing wet food diet wild cats get moisture food nature drink lot water i thought hurt give cat treat couple times week even touch it i tried mixing regular dry food give texture ate dry food around it i sure preference cat particular cat food
# Original summary: cat will not eat it
# Predicted summary:  my cat loves it
#
#
# Review: best bet figure allergic to it broken heart nurse i believe best him i cannot argue results seen since putting formula i hate cost worth every cent and i use 5 coupons whenever i buy helps lot and specialist said i give probiotics found local health food stores mimic benefits breastmilk one last thing i tried get covered insurance unsuccessful but luck all probably prescription side insurance medical part some cover pediatrician's office call child's clinical data necessity good luck
# Original summary: made all the difference in the world
# Predicted summary:  a great product
#
#
# Review: i fortunate work hot water maker thing works well gives piping hot water dissolves coffee dust matter seconds barely requiring stir br br the coffee strong tastes similar starbucks italian roast might get store same robust burnt something i personally prefer still pretty damn good instant coffee br br having irregular sleep patterns coffee spared embarrassment falling asleep countless meetings it works tastes good holds cream well only drawback leaves muddy residue bottom cup but is not bad it's sanka
# Original summary: this coffee has saved me more than once
# Predicted summary:  good for the price
#
#
# Review: so happy find item amazon purchased multi bran chex around christmas grocery store able find since it delicious eat breakfast cereal party mix
# Original summary: multi bran chex cereal
# Predicted summary:  great
#
#
# Review: the jar small picture shows web it 1 2 half empty already open jar i hope helpfull buy product
# Original summary: manuka honey
# Predicted summary:  poor quality
#
#
# Review: no best by expiration date package br br for bad prevent ordering otherwise good popcorn i need questionable additives make popcorn yellow leaves colorful gross residue pan popping and flavor popcorn itself along whatever i want add own cannot carry day i find product stand own br br other you need 4 oz half bag completely fill standard whirley pop cut back needed very salty taste may want start much less salt offered salt taste till find amount works you
# Original summary: good bad
# Predicted summary:  good but not great
#
#
# Review: wow taste great very good flavor very fresh tasting i cut small pieces kids my whole family enjoys chewy beef steak i buy again great road trips a quick snack
# Original summary: great tasting
# Predicted summary:  delicious
#
#
# Review: these useful giving geriatric dog medications thank much treats
# Original summary: wonderful idea
# Predicted summary:  dog chew
#
#
# Review: like raspberry lemonade it mild tea flavor pleasant overpowering since already lug tons bottled water costco great also buy bottled drinks the crystal light packets make drinking water breeze since i started using packets i keep water refrigerator mix tea i am reading shopping i also love make slushies drink mix just put bottle freezer hours shake vigorously i say on go flavors bit addictive with much variety flavors drinks really make life little fun br br the rebecca review
# Original summary: a little sweet but still delicious
# Predicted summary:  refreshing drink
#
#
# Review: this second time we have ordered newman's organic raisins quite pleased the raisins plump tasty right texture as juicy raisin be we received timely manner quite happy product we ordering would definitely recommend others
# Original summary: juicy and plump
# Predicted summary:  delicious
#
#
# Review: i make pickled garlic asparagus every year sell roadside stand my garlic asparagus big seller i make without important ingredient hard find store especially small community great find me
# Original summary: important ingredient to recipe
# Predicted summary:  great product
#
#
# Review: i fortunate find product local grocery store available while this must seasoning good know available amazon if travel major city chicago available ethnic markets especially polish neighborhoods
# Original summary: excellent seasoning
# Predicted summary:  the best
#
#
# Review: this product worked well us and delivery breeze it arrived 2 3 days
# Original summary: great food my cat loves it
# Predicted summary:  great product
#
#
# Review: orange tangerine switch crisp carbonated citrus beverage unlike sugar laden brethren switch leave sticky film mouth finished drinking it presumably sugar added drink my complaint price 1 per can get whole lot bang buck especially since get 12 oz regular soda much lower price i guess that is price pay something that is better you
# Original summary: delicious
# Predicted summary:  great alternative to soda
#
#
# Review: around various dog foods looking answer buying blue buffalo life protection thrown month also quit eating grass blend blue buffalo old dog food poured bowl loved it picky dog well dog foods eat know blue buffalo superior ingredients grocery stores food made big difference way looks act well clean dog throw times week worth extra cost cheap dog food great dog food dogs died poisons food cheap artificial ingredients love dog much would anything spend anything keep around longer you
# Original summary: great dog food
# Predicted summary:  my dog loves this food
#
#
# Review: love hershey's kisses i bought good price 19 with 5 discount cost 14 i may order price goes down
# Original summary: love them
# Predicted summary:  great price
#
#
# Review: diet drinks which i drink water which nice yearn something taste iced tea the texas kind unsweetened and heat drink lot tea house i have tried kinds teas including specially blended iced tea froo froo specialty teas hold candle tazo iced tea why it distinctive rich full tea taste and i am sorry sweet tea covers true tea flavor it's shame way buy it beats able buy all have iced tea fanatic house this new crack tea i know mine
# Original summary: iced tea for iced tea connoisseurs
# Predicted summary:  a pleasant surprise
#
#
# Review: if enjoy friends i would avoid product br br i pretty good friends longer such this product gave i would consider borderline diarrhea br br i buy claim fiber good digestive tract i could eat steak every meal 100 normal br br having explosive farts normal bowel health
# Original summary: this will give you bad gas
# Predicted summary:  good but not as good as the other ones
#
#
# Review: wonderful product many ways cats coat shedding less beautifully silky they love turkey flavor price bad quality highly recommend
# Original summary: cat heaven
# Predicted summary:  great product
#
#
# Review: br total carb 34 g br sugars 33g br br monster br calories 10 br total carb 3g br sugars 3g br br in fairness i am sure monster less bad stuff low carb br still matter slice it less bad stuff br br i really enjoyed taste loved energy no fear br i cannot figure drink taste lighter yet sugar does br if someone who is concerned extra calories give no fear try br it delivers powerful engery boost
# Original summary: great taste powerful boost
# Predicted summary:  a bit too sweet for me
#
#
# Review: i think green drink chocolatey delicous i problem w taste texture alot people do however taste really quite good compared green drinks in fact tastes good i hope i really getting green benefit promises amazing grass promises one best the best green drink market the chocolate cover green taste like chocolate good thing the texture however little gritty canister states dissolve better little water first add liquid i continue drinking get greens tastes good amazon great price
# Original summary: great green drink
# Predicted summary:  great taste and healthy
#
#
# Review: like it she will take it drop it if likes rare she will take eat right spot if loves very rare she will take it hide it act paranoid saw hide it so she will go get re hide multiple times satisfied spying secret wish devour moment then she will sneak family gone sleep savor peace so i cannot really tell today's lamb trachey chewz treat went i certain loves it thanks clear conscience pet producing healthy greatly desired treat
# Original summary: loved by my picky eater
# Predicted summary:  magic for the first
# Review: i have browsing amazon tea sellers authentic restaurant style thai tea this one exactly i looking for br br amazing taste extremely easy make instructions provided show easy ways make tea traditional long boil br br however morning rush i simply use tea coffee machine 1 2 tbsp per cup water comes excellent cream sugar br br definitely recommended
# Original summary: excellent for those looking for restaurant thai tea taste
# Predicted summary:  delicious
#
#
# Review: love love love metromint water chocolatemint favorite i like drink water like calories i drink i despise soda metromint water calories tastes great it extremely refreshing especially hot day i take water bottle metromint refreshing go drink i want splurge tap water if less expensive i would purchase often
# Original summary: best bottled water out there
# Predicted summary:  great soda
#
#
# Review: i reluctant order item due negative reviews however i bit bullet subscribed i love coconut milk i buying health food store love price well i received first order perfect it well packed no dented cans the cans exactly store product originating thailand the price subscribing amazing perfect food it addition paleo primal recipes br br i love amazon i complained 1 order i order amazon regularly made right immediately that's i worried order milk i soooo glad i did
# Original summary: reluctant to order but very happy i did
# Predicted summary:  great product
#
#
# Review: i excited see product because another poster mentioned i tend eat way much regular peanut butter i spread half pita fruit preserves half taste terrible they try make nutty almost really salty taste it it probably worst thing i have ever eaten i try make tolerate it good
# Original summary: terrible pb substitute
# Predicted summary:  not bad
#
#
# Review: i really come love san francisco bay coffees they great robust flavor packaging unique much nicer hard little plastic k cups the way separated whole 36 cups exposed air one time getting stale genius can't wait new flavors come out great price too
# Original summary: very rich dark coffee
# Predicted summary:  great coffee
#
#
# Review: finally found products i like much hope get different kinds chips calbee
# Original summary: very good
# Predicted summary:  great chips
#
#
# Review: wish made version color treated hair that would perfect me in case i like shampoo enough i going try corresponding conditioner hopes deliver results br br update i tried conditioner it's quite honestly volumizing conditioner i used actually delivers promise i fine straight hair much fullness as result i tried every volumizing hair product there my hair definitely fuller using conditioner matter shampoo i use it maintains fullness shampoos it's also soft easy style without doubt brand become new favorite
# Original summary: very nice shampoo
# Predicted summary:  great shampoo
#
#
# Review: the nuts arrived quickly with reg 5 shipping they came adequately packaged 5lb thick clear double plastic bags there's oily residue left fingers handling nuts thus i say they are dry roasted well toasted actually well taste pronounced burned taste them since there're similar cashew offerings amazon state roasted i naively wishing un roasted still much less expensive less burned grocery stores covered sugar salt oil etc
# Original summary: to me these are well toasted or dry roasted
# Predicted summary:  not as good as the original
#
#
# Review: this thanksgiving evening four us tried starbucks vanilla roast all us disappointed comments included 'bitter' 'too 'flat' 'vanilla smell overcomes coffee aroma' when drinking vanilla roast bitterness outweighs coffee taste vanilla invisible most coffees average one different it star comes coffee field if serious coffee connoisseur would like find great coffee best served investigating premium roasts available often less mainstream roasters
# Original summary: disappointing not a premium roast
# Predicted summary:  best coffee ever
#
#
# Review: this quick easy make never really ever one way vermicelli anything else matter br br a brown rice version slightly healthier great us whose staple consists rice 3 5 servings per bag 209 calories 47 1 g carbs 6 g fiber 3 2 g per serving
# Original summary: delicious
# Predicted summary:  great for diabetics
#
#
# Review: i am glad i discovered cameron's amazon maybe available stores i live every flavor i have tried delicious caramel creme particular favorite the caramel flavor noticeable without overwhelming taste coffee itself also i think flavored coffees use flavor cover substandard coffee cameron's always tastes like coffee good quality well
# Original summary: one of the best flavored coffees
# Predicted summary:  great coffee
#
#
# Review: i thought stuff tasted alot sugary carby packaged soymilk by reading reviews i informed low protein high sugar content i read label was i 2 canisters ugg hopefully mix soy plant protein powder i'm vegan better tasting nutritious
# Original summary: convienent and does not go bad but too sugary
# Predicted summary:  not bad
#
#
# Review: these recommended vet i get better price here my dogs love teeth looking good
# Original summary: dog loves them
# Predicted summary:  great product
#
#
# Review: delicious hazel nut taste bite size wafer cookie highly recommended buy again remind hazel nut coffee creamer
# Original summary: delicious
# Predicted summary:  delicious
#
#
# Review: this far one favorite hot sauces next mother in laws amazing the flavor sauce always right mix sweet hot i known there i found sauce 15 years ago day i found much compare market comes nice flavorful sweat session thanks rasta fire kick great taste
# Original summary: one of the best
# Predicted summary:  great flavor
#
#
# Review: truth kind ever purchased cannot make fair comparison br br what can say however even go manufacturer's website deal amazon better deal pricewise plus comes cans instead bags plus comes scoop need measure anymore br br and lastly inclusion hot chai latte famous barista recipe truth always said making chai latte wasn't barista recipe latte adds milk never did br br so that is take this hope helps decision making
# Original summary: possibly the best tasting definitely the best value
# Predicted summary:  best chai ever
#
#
# ...
# Original summary: hard as a rock with about as much flavor
# Predicted summary:  delicious
#
#
# Review: i wish once someone would leave taste these every time i purchase son eats whole box he loves fruity pebbles obviously excellent product and gluten free
# Original summary: my son eats the hole box
# Predicted summary:  great snack
#
#
# Review: was bit skeptical plants shipped ca they arrived excellent condition they far bigger robust i would thought out 4 plants one leaf turning cant find anything locally even comes close quality plants i surely return customer received 1 red prayer plant one green prayer plant one philo one devils ivy great seller
# Original summary: arrived in great condition
# Predicted summary:  great product but
#
#
# Review: however first thing note going hammered strong garlic onion taste and significant remind next day lol but hydro oils fructose corn syrup stuff longer snacks not these i replaced regular potato chips even baked ones these i think they are better going try sea salted vinegar ones well plains will report following id give 4 5 i could br one thing note if soft skin mouth may scratch up
# Original summary: a tasty snack without the bad stuff
# Predicted summary:  good but not as good as the ones
#
#
# Review: not writer reese cheesy popcorn best area michigan i use buy kroger's we start buying amazon kroger's stop stocking reese cheesy popcorn i hit net search it it tasty popcorn better power popcorn salt that is tried family i highly recommend reese cheesy popcorn all
# Original summary: best popcorn butter salt
# Predicted summary:  great popcorn
#
#
# Review: my first two babies never bottle i was am proud nursing mother third little guy hungry i supplement satisfy him my mother i lot research formula specifically organic i ended choosing i could happier i feel good feeding baby formula i approve ingredients really likes stuff it smells nice never spits up delight eating
# Original summary: the good stuff
# Predicted summary:  my cats love it
#
#
# Review: i pleased brand coffee great flavor waste great design will one favorite blends now
# Original summary: enjoy this brand of coffee
# Predicted summary:  great coffee
#
#
# Review: we used victor fly bait 3 seasons can't beat it great product
# Original summary: flies begone
# Predicted summary:  great product
#
#
# Review: i like good cup joe friends turned us kona coffee instant fans but cost killing us so i saw amazon new grocery line i checking price this great cup kona price i hate bitter coffee smooth
# Original summary: savory and smooth
# Predicted summary:  great coffee great price
#
#
# Review: i love company i love products particular flavor combo work there nice vinegar tang front jelly donut aroma sweetness downright odd it nice idea i am sticking good old malt vinegar variety
# Original summary: stick with the sea salt vinegar
# Predicted summary:  not bad
#
#
# Review: i really like much i like white cheddar these kind mild salty cardboard kind flavor i expected cheese flavor kind fake flavor me now i know much flavor mozzarella i think even tried duplicate it on hand 18 yr old son thought pretty good also likes burger king mcdonalds too ya go
# Original summary: not my favorite cheez it flavor
# Predicted summary:  good but not great
#
#
# Review: comes time rinse out wash easily leaving residue i suspicious first hair feel squeaky clean rinsing hair dry i could see clean soft oily stayed way day even wearing hat both shampoos also give weight hair which thinning hair i really appreciate my wife also reported shampoo felt need use conditioner the reader see essentially review clear scalp products tested difference one volumizing root boost probably leaves hair little weight but expect give practice buying cheapest shampoos purchase one future
# Original summary: creamy shampoo that really is different
# Predicted summary:  not the best
#
#
# Review: i excited see new line sriracha sauce grocery store i scooped first day i saw it br br this sauce packed flavor tangy showcases flavors chili garlic right front it hot huy fong sriracha sauce green lid also tangier flavor br br i definitely recommend sauce
# Original summary: excellent sauce milder than the green lid
# Predicted summary:  great for hot sauce
#
#
# Review: i use espresso electric espresso maker make hot iced lattes it's bold br br i usually buy coffee a href http www amazon com gp product lavazza caffe espresso ground coffee 8 ounce cans pack 4 a wanted try something little punch this coffee smooth i e acidic packs big flavor if looking coffee packs good punch one if want subtlety i would go lavassa caffe espresso
# Original summary: very bold
# Predicted summary:  great coffee
#
#
# Review: this variety pack good new keurig trying figure k cups like lot decaf k cups package
# Original summary: good but there are a lot of decaf k cups
# Predicted summary:  good coffee
#
#
# Review: i brought ohio texas haven't found stores yet i used dip 2c sour cream 2 seasoning mix let sit least hour neighbors get enough it it kick heat it enough make addictive salty so glad find amazon i will trying general seasoning too i get new supply
# Original summary: love it as a dip
# Predicted summary:  delicious
#
#
# Review: my son loves earth's best baby food he enjoys vegetables much fruits he problem digesting food never spits up
# Original summary: best baby food ever
# Predicted summary:  baby loves it
#
#
# Review: i looking k cup storage solution i came across stackable baskets i happy i feel necessary spend 25 k cup storage solution this fits budget looks really nice next keurig i am pleased baskets
# Original summary: very nice baskets
# Predicted summary:  great product
#
#
# Review: i purchased item christmas gifts two people list difficult buy for the price within budget i purchased two eligible free super saver shipping always big plus the packaging attractive larger i expecting 18 5 x7 x2 although i idea quality salmon hence 4 star rating i receive gift i would pleased i would consider buying item i need gift 20 00
# Original summary: as a gift
# Predicted summary:  great product but overpriced
#
#
# Review: i fallen love ginger i love spicy hot sweet flavor i tried chews but i like much i might not
# Original summary: i love this ginger
# Predicted summary:  delicious
#
#
# Review: green beans pears peas like appears front veggies predominant ingredient ingredient list back and color food itself tells much vegetable pear something spinach would think color would closer green rather pear mango i have made tons baby food home anything good amount spinach since place first list first front ingredients show otherwise turns green suppose keep small amount avoid deterring kids color br in end he is getting organic pear side organic veggies dose omega 3s better goldfish crackers day
# Original summary: both kids love it
# Predicted summary:  a healthy alternative to my diet
#
#
# Review: the americolor amerimist edible paint airbrush color gold sheen worked great airbrush spray on awesome color photos
# Original summary: just what i needed
# Predicted summary:  great product
#
#
# Review: very good tasting slightly infused coffee real vanilla this good drink black coffee even take regular non sweetened creamer also try caramel one too tasty well
# Original summary: especially good for those who like their coffee black
# Predicted summary:  great coffee
# Review: i found flavor store once searched forever find again then went amazon purchased was little afraid buying food amazon no fear like buy store could find cheaper amazon too
# Original summary: pop tarts semi frosted roll flavor
# Predicted summary:  great product
#
#
# Review: what ask for this popcorn great taste nearly 100 pops i use stir crazy popper plain old crisco oil variety seasonings br br we go lot popcorn one we will ordering again
# Original summary: this is great popcorn
# Predicted summary:  great popcorn
#
#
# Review: my husband loves these they pretty good they moist like real jerky sense otherwise texture similar i wish variety sweet i definitely recommend trying getting entire package luckily i got try them good
# Original summary: pretty good
# Predicted summary:  yummy
#
#
# Review: item tasted plain crumbly did taste like described we disappointed product
# Original summary: plain
# Predicted summary:  not bad
#
#
# Review: ive love flavor infused oils they make scrambled eggs saut eacute ing veggies amazing they add taste without adding bunch salt pepper i loved much i got set grandmother loved too she made quiche
# Original summary: love it
# Predicted summary:  delicious
#
#
# Review: post brand cereal maple syrup taste them one cereals i actually enjoyed enough i would choose bacon eggs br this maple syrup taste waffle crisp though honey roasted nut taste like box suggests however something taste cereal itself beyond honey flavor reminds waffle crisp br br once more i am big breakfast cereal i could really see buying future i likely will assuming i find local grocery store so fan late waffle crisp cereal plain looking something different try out
# Original summary: a pleasant surprise and quite possibly my new favorite cereal
# Predicted summary:  good cereal
#
#
# Review: bought 17 year old he loves them saves work out very filling great deal thru amazon
# Original summary: kashi bars
# Predicted summary:  great product
#
#
# Review: i received order coffee i tried immediately delicious i put two tablespoons coffeemate french vanilla sugar free creamer total 30 calories 2 carbs i heaven tastes good anything starbucks
# Original summary: very good coffee
# Predicted summary:  delicious
#
#
# Review: healthier alternative regular chips i admit great crunch something kettle chip the texture also nice similar great potato flavor the big issue sodium level after four five chips they are almost unbearable salt really stop tasting anything salt a review nutritional facts showed sodium per serving almost double standard potato chip serving original flavor i cannot imagine salt pepper style must like br br i would buy regularly cut salt 75 because salt factor i think call healthy alternative chips
# Original summary: holy salt batman
# Predicted summary:  tasty but not as good as the other brands
#
#
# Review: is snack bar meal bar reviews saying snack picture shows snack but description says meal im looking meal bars awesome i love them and deal i need meal bars snack can anyone help
# Original summary: question
# Predicted summary:  great snack
#
#
# Review: we going local restaurant serve thursday everyone tried taste right little broccoli i picked one day local store was little suspect adding boiling water this what big surprise very good soup i added frozen chopped broccoli simmer let tell make special trip anymore cheddar broccoli soup you'll surprise well taste
# Original summary: cheddar broccoli soup
# Predicted summary:  great for cooking or lunch
#
#
# Review: this nice treat the box contains pasta shape rice granules similar couscous it also dried broccoli packet velveeta as would expect boxed meal kit preparation simple fast if concerned messing up be the flavor yummy cheesy course artificial twang if bother you i recommend it it's best food type i have while
# Original summary: really delicious
# Predicted summary:  good for a quick meal
#
#
# Review: i love celestial seasoning's madagascar vanilla red tea sadly becoming harder harder find stores but order item i placed order it order randomly canceled company the seller listed abc wholesale listed red tag sale even though exact item buy another source great tea i personally think works great combination teas favorite combination four bags tea one bag plum black tea make gallon pitcher tastes great hot cold
# Original summary: love the tea do not order this item
# Predicted summary:  great tea
#
#
# Review: great roasted 10 15 minutes 350 degrees overdo roasting roasting provides great taste reduces moisture content sweetens flavor
# Original summary: roast these nuts
# Predicted summary:  delicious
#
#
# Review: i love almonds perfect snack need eat lot feel satisfied also since lot flavor feel mouth satisfied well the wasabi hot actually i wish little hotter soy adds little bit saltiness i recommend like wasabi peas want something nutritional value
# Original summary: perfect snack
# Predicted summary:  delicious
#
#
# Review: really light even color gray pieces oats aroma nice creamy texture same nutritional values big brand price reason giving 5 stars
# Original summary: better than the big brand name oatmeal
# Predicted summary:  good but not great
#
#
# Review: it br br the red husk skin adds additional flavor if ever tried cooking own know easy burn skin getting come just right real art br br planters mastered art their redskin spanish peanuts consistently plump fresh tasting perfectly roasted the sea salt variety terrific too br br buying bulk like seems like overdoing it peanut lover family may surprised quickly they will disappear br br and reviewers pointed out spanish peanuts seem getting harder find days grab 'em can
# Original summary: for the true peanut connoisseur
# Predicted summary:  the only salt i have ever had
#
#
# Review: i wasn t sure i would even like keurig coffee maker i like strong coffee this wonderful us like mild brews plus little k cups convienient i recommend product
# Original summary: im glad i purchased this great price
# Predicted summary:  great coffee
#
#
# Review: bacon salt nah it it's like jerky seasoning not bad got gluten i cannot use it i am taking points though mentioning it
# Original summary: not very bacony
# Predicted summary:  not as good as the other brands
#
#
# Review: nantucket blend coffee one favorites i suprised single box every time i ordered 2 pack my fault reading closer i order price 1 24 count
# Original summary: price surprise
# Predicted summary:  great coffee
#
#
# Review: i one yearned old style bitter crisp taste quinine without syrupy finish schweppes always close i could get good enough i read reviews fever tree q decided try fever tree based descriptions not bad would like distinction schweppes especially price trying q next
# Original summary: great expectations
# Predicted summary:  great product but
#
#
# Review: this trader joe's product good quality but buy straight tj's this retailer selling product twice price tj's sells reprehensible shame you
# Original summary:
# Predicted summary:  good product
#
#
# Review: i expecting plain old cup coffee i popped keurig imagine surprise turned party mouth this coffee delicious i definitely buy again
# Original summary: great tasting
# Predicted summary:  great coffee
#
#
# Review: substitute yes go ebay order soon to be expired gigantic bottles real deal expensive savings going starbucks first place negligible br br torani sauces syrups great right we use tassimo system with latte espresso discs cappuccino espresso fantastic if going lattes get syrups consistency much better this stuff great mixed hot chocolate ice cream well i have even made milkshakes it in fact i have made many things stuff i think next time i am going go sugar free version
# Original summary: yummy stuff good deal
# Predicted summary:  great for baking
#
#
# Review: this favorite ese pod acceptable price the lucaffe brand favorite i also tried blucaffe jamaican blue blend mr exclusive pure arabica serving they good classic tastier mr exclusive i think definitely better blucaffe considering price this robusta arabica blend enjoyable everyone tried impressed drinking this one stomache starbucks brand ese pod excellent crema subtle sweetness rich
# Original summary: a perfect blend
# Predicted summary:  great coffee
# Review: a good product i received one puree function didnt work sent back ordered another one 2nd one problem i figured two i received problem i must one i read reviews saw others saying take machine apart put black belt back on we works like champ whatever cause issue need better quality control
# Original summary: frustrated but its a good product
# Predicted summary:  good product but poor packaging

# %%
test_review = input("Enter a review: ")
test_sequence = x_tokenizer.texts_to_sequences([test_review])
test_sequence = pad_sequences(test_sequence, maxlen=max_len, padding='post')
decode_sequence(test_sequence.reshape(1, max_len))
# Out:
# Enter a review: sandwich was spicy. the sause was amaizing
# ' good but not great'
